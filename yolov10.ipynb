# %%
import shutil
import os

def remove_all_contents(directory_path):
    try:
        # List all files and directories in the specified directory
        for filename in os.listdir(directory_path):
            file_path = os.path.join(directory_path, filename)
            # Check if it is a file or directory
            if os.path.isfile(file_path) or os.path.islink(file_path):
                os.unlink(file_path)  # Remove the file or link
            elif os.path.isdir(file_path):
                shutil.rmtree(file_path)  # Remove the directory and its contents
        print(f"All contents removed from directory: {directory_path}")
    except Exception as e:
        print(f"An error occurred: {e}")

# Example usage
directory_path = '/kaggle/working/'
remove_all_contents(directory_path)
# Out:
# All contents removed from directory: /kaggle/working/model

# %%
# !pip install -r /kaggle/input/yolov10-thu/yolov10-main/requirements.txt

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="VLA4NjLsWKHPeUJ4Qj17")
project = rf.workspace("dataset-conversion-ipkwb").project("visdrone-uhzsx")
dataset = project.version(4).download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# [WARNING] we noticed you are downloading a `yolov8` datasets but you don't have `ultralytics` installed. Roboflow `.deploy` supports only models trained with `ultralytics==8.0.196`, to intall it `pip install ultralytics==8.0.196`.
# ...
# Extracting Dataset Version Zip to VISDRONE-4 in yolov8:: 100%|██████████| 17264/17264 [00:05<00:00, 3327.92it/s]

# %%
# %cd /kaggle/working/VISDRONE-4
# !rm data/mydataset.yaml # nếu có file thì xóa
# !echo 'train: /kaggle/working/VISDRONE-4/train' >> mydataset.yaml
# !echo 'val: /kaggle/working/VISDRONE-4/valid' >> mydataset.yaml
# !echo 'test: /kaggle/working/VISDRONE-4/test' >> mydataset.yaml
# !echo 'nc: 10' >> mydataset.yaml
# !echo "names: ['Awning-tricycle', 'Bicycle', 'Bus', 'Car', 'Motor', 'Pedestrian', 'People', 'Tricycle', 'Truck', 'Van']" >> mydataset.yaml
print('Create yaml file')
# Out:
# /kaggle/working/VISDRONE-4
# rm: cannot remove 'data/mydataset.yaml': No such file or directory
# Create yaml file

# %%
import os

def create_directory(directory_path):
    try:
        # Tạo thư mục mới
        os.makedirs(directory_path, exist_ok=True)
        print(f"Đã tạo thư mục: {directory_path}")
    except Exception as e:
        print(f"Đã xảy ra lỗi khi tạo thư mục: {e}")

# Ví dụ sử dụng
new_directory_path_1 = '/kaggle/working/model' #path for model
new_directory_path_2 = '/kaggle/working/requirement' #path for requirement installation

create_directory(new_directory_path_1)
create_directory(new_directory_path_2)
# Out:
# Đã tạo thư mục: /kaggle/working/model
# Đã tạo thư mục: /kaggle/working/requirement

# %%
import shutil
import os

def copy_directory(source_dir, destination_dir):
    # Kiểm tra xem thư mục nguồn có tồn tại không
    if not os.path.exists(source_dir):
        print(f"Thư mục nguồn không tồn tại: {source_dir}")
        return

    # Tạo thư mục đích nếu nó không tồn tại
    if not os.path.exists(destination_dir):
        os.makedirs(destination_dir)

    # Sao chép toàn bộ nội dung của thư mục nguồn vào thư mục đích
    try:
        shutil.copytree(source_dir, destination_dir, dirs_exist_ok=True)
        print(f"Đã sao chép thư mục từ {source_dir} đến {destination_dir}")
    except Exception as e:
        print(f"Đã xảy ra lỗi: {e}")

# Ví dụ sử dụng
source_directory = '/kaggle/input/yolov10-thu/yolov10-main'
destination_directory = '/kaggle/working/requirement'
copy_directory(source_directory, destination_directory)
# Out:
# Đã sao chép thư mục từ /kaggle/input/yolov10-thu/yolov10-main đến /kaggle/working/requirement

# %%
import subprocess
import os

def install_editable_mode(package_dir):
    try:
        # Change the current working directory to the package directory
        os.chdir(package_dir)
        
        # Run the pip install command
        result = subprocess.run(['pip', 'install', '-e', '.'], capture_output=True, text=True)
        
        # Check if the command was successful
        if result.returncode == 0:
            print(f"Successfully installed package in editable mode from {package_dir}")
        else:
            print(f"Failed to install package. Error: {result.stderr}")
    except Exception as e:
        print(f"An error occurred: {e}")

# Example usage
package_directory = '/kaggle/working/requirement'
install_editable_mode(package_directory)

# %%
import os
import urllib.request

# Create a directory for the weights in the current working directory
# weights_dir = os.path.join(os.getcwd(), "weights")
# os.makedirs(weights_dir, exist_ok=True)

# URLs of the weight files
urls = [
#     "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10n.pt",
#     "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10s.pt",
    "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10m.pt",
#     "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10b.pt",
#     "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10x.pt",
#     "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10l.pt"
]

# Download each file
for url in urls:
    file_name = os.path.join("/kaggle/working/model", os.path.basename(url))
    urllib.request.urlretrieve(url, file_name)
    print(f"Downloaded {file_name}")
# Out:
# Downloaded /kaggle/working/model/yolov10m.pt

# %%
import subprocess

def uninstall_library(library_name):
    try:
        subprocess.check_call(['pip', 'uninstall', '-y', library_name])
        print(f'Successfully uninstalled {library_name}')
    except subprocess.CalledProcessError:
        print(f'Error uninstalling {library_name}')

# Example usage
library_name = 'wandb'  # Replace with the name of the library you want to uninstall
uninstall_library(library_name)
# Out:
# Found existing installation: wandb 0.16.6
# Uninstalling wandb-0.16.6:
#   Successfully uninstalled wandb-0.16.6
# Successfully uninstalled wandb

# %%
# !yolo task=detect mode=train epochs=100 batch=16 plots=True model=/kaggle/working/model/yolov10m.pt data=/kaggle/working/VISDRONE-4/mydataset.yaml
# Out:
# New https://pypi.org/project/ultralytics/8.2.22 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.34 🚀 Python-3.10.13 torch-2.0.1+cu117 CUDA:0 (Tesla P100-PCIE-16GB, 16276MiB)
# ...

# %%
import shutil
import os

def zip_folder(folder_path, zip_name):
    # Ensure the zip name does not include the '.zip' extension
    if zip_name.endswith('.zip'):
        zip_name = zip_name[:-4]
        
    # Create a zip file from the folder
    shutil.make_archive(zip_name, 'zip', folder_path)
    print(f"Folder {folder_path} has been zipped into {zip_name}.zip")

# Example usage
folder_to_zip = '/kaggle/working/requirement/runs/detect/train'
output_zip_file = '/kaggle/working/weights'
zip_folder(folder_to_zip, output_zip_file)
